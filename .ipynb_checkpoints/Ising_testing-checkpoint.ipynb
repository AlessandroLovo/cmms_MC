# %%
from Ising import *
# %matplotlib notebook

# %%
I = Ising(dimension=2,N_spins=100,boundary='periodic')
I.average_magnetization()
I_fin = I.copy()

# %%
I_fin,df = evolve(I_fin,k=2,t_max=1000000,check_time=1,log_time=10000,max_updates=10000000)
I_fin.average_magnetization()
# Out:
#  15%|█▌        | 151772/1000000 [00:16<01:54, 7408.17it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4c381b32a8cc> in <module>()
# ----> 1 I_fin,df = evolve(I_fin,k=2,t_max=1000000,check_time=1,log_time=10000,max_updates=10000000)
#       2 I_fin.average_magnetization()
#
# /media/alessandro/OS/Users/ale57/Documents/1. universita'/ANNO IV (2019-2020)/second semester/Computational Methods for MS/spiro/MC/Ising/Ising.py in evolve(obj, t_max, k, h, criterion, check_time, logfile, log_time, max_updates)
#     289             spin_sum += I.spins[I.get_index(indexs)].value
#     290             indexs[i] -= 2
# --> 291             spin_sum += I.spins[I.get_index(indexs)].value
#     292             indexs[i] += 1
#     293         delta_E += -2*I.spins[j].value*(h + k*spin_sum)
#
# /media/alessandro/OS/Users/ale57/Documents/1. universita'/ANNO IV (2019-2020)/second semester/Computational Methods for MS/spiro/MC/Ising/Ising.py in get_index(self, indexs)
#      98                 j += indexs[0]
#      99             else:
# --> 100                 j += np.product((self.N_spins + 2)[:i])*indexs[i]
#     101         return j
#     102
#
# KeyboardInterrupt:
#  15%|█▌        | 151772/1000000 [00:30<01:54, 7408.17it/s]

# %%
plt.figure()
plt.contourf(I_fin.view())
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
keys = ['spec_E', 'm', 'acceptance','wall_density']

plt.figure()
for key in keys[-1:]:
    plt.plot(df['step'],df[key],label=key)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ks = [0.01, 0.1, 1, 10, 100]
for k in ks:
    I_fin,t_h,a_h,e_h,m_h = evolve(I,k=k,t_max=100000,check_time=1000)
    plt.figure()
    plt.plot(t_h,np.array(e_h)/(k*len(I.free_index_list)))
    plt.plot(t_h,np.array(m_h))
# Out:
# 100%|██████████| 100000/100000 [00:01<00:00, 74954.50it/s]
# 100%|██████████| 100000/100000 [00:01<00:00, 75880.85it/s]
# 100%|██████████| 100000/100000 [00:01<00:00, 71747.27it/s]
# 100%|██████████| 100000/100000 [00:01<00:00, 68616.38it/s]
# 100%|██████████| 100000/100000 [00:01<00:00, 69232.71it/s]

# %%
ks = np.linspace(0.001,10,100)
ms = []

for i,k in enumerate(ks):
    if i%10 == 0:
        print(i)
    I_fin,t_h,a_h,e_h,m_h = evolve(I,k=k,t_max=100000,check_time=1)
    ms.append(np.mean(m_h[:-10000]))
# Out:
# 100%|██████████| 100000/100000 [00:07<00:00, 14188.23it/s]
# 100%|██████████| 100000/100000 [00:06<00:00, 14427.67it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13386.11it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12791.79it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13072.88it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13345.12it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13051.08it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13336.34it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13282.57it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13141.14it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13010.96it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12701.06it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13407.43it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13527.09it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13287.06it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13446.10it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13113.26it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12769.47it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13631.23it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13227.93it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13412.94it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13555.07it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13561.06it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13322.60it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13317.18it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12834.78it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12913.24it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13043.04it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13490.27it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13365.53it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13414.57it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13498.53it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13578.20it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13203.70it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13258.75it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13016.57it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13366.99it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13125.17it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13016.84it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13276.70it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13381.52it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13319.33it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13380.90it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12930.53it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12984.02it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13307.94it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13234.48it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13791.43it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13040.19it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13394.66it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13640.80it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12749.42it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13044.12it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13285.30it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13548.86it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13396.37it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12970.65it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13604.59it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13345.50it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13629.23it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13029.67it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13082.47it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13406.58it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13271.11it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13021.77it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13149.34it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13448.31it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13020.67it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12746.34it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12922.99it/s]
# 100%|██████████| 100000/100000 [00:08<00:00, 12145.74it/s]
# 100%|██████████| 100000/100000 [00:08<00:00, 12440.90it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13733.49it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13489.41it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13715.78it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12793.66it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12809.22it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13267.00it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13186.65it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13208.83it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12909.88it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13168.60it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13578.14it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13393.84it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13636.45it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13498.44it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13059.06it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12902.93it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12976.59it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13239.25it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12920.04it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 12988.77it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13983.12it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13678.90it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13419.35it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13714.71it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 14125.50it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 14050.94it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13518.81it/s]
# 100%|██████████| 100000/100000 [00:07<00:00, 13990.25it/s]

# %%
plt.figure()
plt.scatter(ks,ms)
plt.title('D = 1')
plt.xlabel('k')
plt.ylabel('m')
# Out:
# Text(0, 0.5, 'm')

# %%
plt.figure()
plt.scatter(ks,ms)
plt.title('D = 2')
plt.xlabel('k')
plt.ylabel('m')
# Out:
# Text(0, 0.5, 'm')

# %%
I_fin,t_h,a_h,e_h,m_h = evolve(I,k=100,t_max=1000000,check_time=1)
print(np.mean(m_h[:-10000]))
# Out:
# 100%|██████████| 1000000/1000000 [01:06<00:00, 15117.66it/s]
# 0.23085297474747463

# %%
k = 10
plt.figure()
plt.plot(t_h,np.array(e_h)/(k*len(I.free_index_list)))
plt.plot(t_h,np.array(m_h))

# %% [markdown]
# ## Theoretical computations

# %%
def p_1(k,z):
    return np.exp(-2*z*k)

def p_2(k,z):
    return np.exp(-2*(z - 2)*k)

def seed_ratio_1(k,z):
    return p_1(k,z)/(1 + p_1(k,z))

def seed_ratio_2(k,z):
    return p_1(k,z)/(1 + p_1(k,z) - p_2(k,z)*z)

# %%
ks = np.linspace(0.3,2,1000)
z = 8

plt.figure()
# plt.plot(ks,seed_ratio_1(ks,z))
plt.plot(ks,seed_ratio_2(ks,z))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
z = 8
plt.figure()
plt.plot(ks,p_1(ks,z) + 1)
plt.plot(ks,z*p_2(ks,z))
# Out:
# <img src="data:image/png;base64,..." width="640">
